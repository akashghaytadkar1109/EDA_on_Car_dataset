# %% [markdown]
# ## **Case study for cars**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
cars = pd.read_csv("/content/drive/MyDrive/Cars Data.csv")

# %% [markdown]
# Q.1 (For Data cleaning) Find all null values in the data set . If there is any null value in any column,then fill with the mean of that column

# %%
cars.head()
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
# 2  Acura         TSX 4dr  Sedan   Asia  ...        29.0  3230.0     105.0   183.0
# 3  Acura          TL 4dr  Sedan   Asia  ...        28.0  3575.0     108.0   186.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia  ...        24.0  3880.0     115.0   197.0
#
# [5 rows x 15 columns]

# %%
cars.shape
# Out:
# (432, 15)

# %%
cars.isnull()
# Out:
#       Make  Model   Type  Origin  ...  MPG_Highway  Weight  Wheelbase  Length
# 0    False  False  False   False  ...        False   False      False   False
# 1    False  False  False   False  ...        False   False      False   False
# 2    False  False  False   False  ...        False   False      False   False
# 3    False  False  False   False  ...        False   False      False   False
# 4    False  False  False   False  ...        False   False      False   False
# ..     ...    ...    ...     ...  ...          ...     ...        ...     ...
# 427  False  False  False   False  ...        False   False      False   False
# 428  False  False  False   False  ...        False   False      False   False
# 429  False  False  False   False  ...        False   False      False   False
# 430  False  False  False   False  ...        False   False      False   False
# 431  False  False  False   False  ...        False   False      False   False
#
# [432 rows x 15 columns]

# %%
cars.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
cars['Cylinders'].fillna(cars['Cylinders'].mean())
# Out:
# 0      6.0
# 1      4.0
# 2      4.0
# 3      6.0
# 4      6.0
#       ...
# 427    5.0
# 428    5.0
# 429    6.0
# 430    4.0
# 431    5.0
# Name: Cylinders, Length: 432, dtype: float64

# %%
cars['Cylinders'].fillna(cars['Cylinders'].mean(),inplace=True)

# %%
cars
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [432 rows x 15 columns]

# %%
cars.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      0
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %% [markdown]
# Q.2) (Values Counts) Check what are the different types of 'Make' are there in our dataset. What is the count(occurance) of each 'Make' in the data?

# %%
cars.head(3)
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
# 2  Acura         TSX 4dr  Sedan   Asia  ...        29.0  3230.0     105.0   183.0
#
# [3 rows x 15 columns]

# %%
cars['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Chrysler         15
# Volkswagen       15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Lexus            11
# Kia              11
# Pontiac          11
# Subaru           11
# Mazda            11
# Buick             9
# Mercury           9
# Lincoln           9
# Suzuki            8
# GMC               8
# Cadillac          8
# Infiniti          8
# Saturn            8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Jeep              3
# Oldsmobile        3
# Scion             2
# MINI              2
# Isuzu             2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# Q.3) Show all the records where 'origin' is Asia or Europe.

# %%
cars.head()
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
# 2  Acura         TSX 4dr  Sedan   Asia  ...        29.0  3230.0     105.0   183.0
# 3  Acura          TL 4dr  Sedan   Asia  ...        28.0  3575.0     108.0   186.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia  ...        24.0  3880.0     115.0   197.0
#
# [5 rows x 15 columns]

# %%
cars[cars['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [281 rows x 15 columns]

# %% [markdown]
# Q.4) (Remving unwanted records) Remove all the records where 'Weight' is above 4000.

# %%
cars.head()
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
# 2  Acura         TSX 4dr  Sedan   Asia  ...        29.0  3230.0     105.0   183.0
# 3  Acura          TL 4dr  Sedan   Asia  ...        28.0  3575.0     108.0   186.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia  ...        24.0  3880.0     115.0   197.0
#
# [5 rows x 15 columns]

# %%
cars['Weight'] > 4000
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 427    False
# 428    False
# 429    False
# 430    False
# 431    False
# Name: Weight, Length: 432, dtype: bool

# %%
# shows record greater than 4000
cars[cars['Weight'] > 4000]
# Out:
#            Make                           Model  ... Wheelbase Length
# 0         Acura                             MDX  ...     106.0  189.0
# 15         Audi  A4 3.0 Quattro convertible 2dr  ...     105.0  180.0
# 17         Audi              A6 4.2 Quattro 4dr  ...     109.0  193.0
# 18         Audi                A8 L Quattro 4dr  ...     121.0  204.0
# 20         Audi                        RS 6 4dr  ...     109.0  191.0
# ..          ...                             ...  ...       ...    ...
# 405  Volkswagen                      Touareg V6  ...     112.0  187.0
# 415  Volkswagen                     Phaeton 4dr  ...     118.0  204.0
# 416  Volkswagen                 Phaeton W12 4dr  ...     118.0  204.0
# 419  Volkswagen                       Passat W8  ...     106.0  184.0
# 420       Volvo                         XC90 T6  ...     113.0  189.0
#
# [103 rows x 15 columns]

# %%
cars[~(cars['Weight'] > 4000)]
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan  ...  3893.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [329 rows x 15 columns]

# %% [markdown]
# Q.5)(Applying function on a column, add some value) Increase all the values of 'MPG_City' column by '3'

# %%
cars.head()
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
# 2  Acura         TSX 4dr  Sedan   Asia  ...        29.0  3230.0     105.0   183.0
# 3  Acura          TL 4dr  Sedan   Asia  ...        28.0  3575.0     108.0   186.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia  ...        24.0  3880.0     115.0   197.0
#
# [5 rows x 15 columns]

# %%
cars['MPG_City']=cars['MPG_City'].apply(lambda x:x+3)

# %%
cars
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [432 rows x 15 columns]
